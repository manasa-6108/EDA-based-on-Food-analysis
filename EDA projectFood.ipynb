# %%
#Project based on EDA Exploratory data analysis food analysis
#step 1 First import libery and initialize the process
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#step 2 Importing date files
st = pd.read_csv('onlinedelivery.csv')

# %%
#step 3 Check the shape
st.shape
st.head()

# %%
st.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#      ...    Less Delivery time High Quality of package       Number of calls  \
# 383  ...             Important               Important             Important
# ...

# %%
# to find the shape of transaction
st.shape
# Out:
# (388, 55)

# %%
#step 4 Check the duplicates
st.duplicated().sum()
# Out:
# 102

# %%
st.drop_duplicates(inplace = True)

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 286 entries, 0 to 369
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Age                                        286 non-null    int64
#  1   Gender                                     286 non-null    object
#  2   Marital Status                             286 non-null    object
#  3   Occupation                                 286 non-null    object
#  4   Monthly Income                             286 non-null    object
#  5   Educational Qualifications                 286 non-null    object
#  6   Family size                                286 non-null    int64
#  7   latitude                                   286 non-null    float64
#  8   longitude                                  286 non-null    float64
#  9   Pin code                                   286 non-null    int64
# ...

# %%
#missing value detaction and  treatment process

# %%
st.isnull().sum()
# Out:
# Age                                          0
# Gender                                       0
# Marital Status                               0
# Occupation                                   0
# Monthly Income                               0
# Educational Qualifications                   0
# Family size                                  0
# latitude                                     0
# longitude                                    0
# Pin code                                     0
# Medium (P1)                                  0
# Medium (P2)                                  0
# Meal(P1)                                     0
# Meal(P2)                                     0
# Perference(P1)                               0
# Perference(P2)                               0
# Ease and convenient                          0
# Time saving                                  0
# More restaurant choices                      0
# Easy Payment option                          0
# ...

# %%
st = spot.dropna(axis=0,how ='any')

# %%
st.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  ...  \
# 0              Post Graduate            4   12.9766    77.5993    560001  ...
# 1                   Graduate            3   12.9770    77.5773    560009  ...
# 2              Post Graduate            3   12.9551    77.6593    560017  ...
# 3                   Graduate            6   12.9473    77.5616    560019  ...
# 4              Post Graduate            4   12.9850    77.5533    560010  ...
#
#      Less Delivery time High Quality of package       Number of calls  \
# 0  Moderately Important    Moderately Important  Moderately Important
# ...

# %%
st.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  285.000000   285.000000  285.000000  285.000000     285.000000
# mean    24.649123     3.270175   12.972982   77.597092  560036.891228
# std      3.021584     1.355994    0.043722    0.053598      30.788329
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.943800   77.563300  560010.000000
# 50%     24.000000     3.000000   12.977000   77.586400  560027.000000
# 75%     26.000000     4.000000   12.998000   77.622700  560066.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
# Make all value lower
for i in st.columns:
    try:
        st[i] = st[i].str.lower()
    except:
        pass

# %%
st = st.replace(['no income', 'below rs.10000', '10001 to 25000', '25001 to 50000', 'more than 50000'], ['0', '<10k', '10k-25k', '25k-50k', '>50k'])
st = st.replace(['yes', 'no', 'maybe'], [1, 0, 2])
st = st.replace(['strongly disagree', 'disagree', 'neutral', 'agree', 'strongly agree'], [1,2,3,4,5])
st = st.replace(['unimportant', 'slightly important','important', 'moderately important', 'very important'], [1,2,3,4,5])

# %%
#5 multvariate analysis

#checking the composition of the categorical variable using visualization & also check the value count & nunique as well.

stdata = st.select_dtypes('object')

stdata.Gender.value_counts()
# Out:
# Gender
# male      163
# female    122
# Name: count, dtype: int64

# %%
stdata.head()
# Out:
#    Gender Marital Status Occupation Monthly Income Educational Qualifications  \
# 0  female         single    student              0              post graduate
# 1  female         single    student           <10k                   graduate
# 2    male         single    student           <10k              post graduate
# 3  female         single    student              0                   graduate
# 4    male         single    student           <10k              post graduate
#
#           Medium (P1)   Medium (P2)   Meal(P1) Meal(P2)  \
# 0  food delivery apps   web browser  breakfast    lunch
# 1  food delivery apps   web browser     snacks   dinner
# 2  food delivery apps   direct call      lunch   snacks
# 3  food delivery apps       walk-in     snacks   dinner
# 4             walk-in   direct call      lunch   dinner
#
#                            Perference(P1)  \
# 0          non veg foods (lunch / dinner)
# 1          non veg foods (lunch / dinner)
# ...

# %%
stdata.Gender.nunique()
# Out:
# 2

# %%
stdata.Gender.value_counts()
# Out:
# Gender
# male      163
# female    122
# Name: count, dtype: int64

# %%
# Group the column based on the question
influence = ['Ease and convenient','Time saving', 'More restaurant choices', 'Easy Payment option',
       'More Offers and Discount', 'Good Food quality', 'Good Tracking system'] 
print(influence)

not_purchase = ['Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
       'Bad past experience', 'Unavailability', 'Unaffordable']
print(not_purchase)

cancelation = ['Long delivery time', 'Delay of delivery person getting assigned',
       'Delay of delivery person picking up food', 'Wrong order delivered',
       'Missing item', 'Order placed by mistake']

delivery = ['Influence of time',
       'Order Time', 'Maximum wait time', 'Residence in busy location',
       'Google Maps Accuracy', 'Good Road Condition', 'Low quantity low time',
       'Delivery person ability', 'Less Delivery time', 'Number of calls', 'Politeness']
# Out:
# ['Ease and convenient', 'Time saving', 'More restaurant choices', 'Easy Payment option', 'More Offers and Discount', 'Good Food quality', 'Good Tracking system']
# ['Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene', 'Bad past experience', 'Unavailability', 'Unaffordable']

# %%
stdata.Gender.value_counts().plot(kind ='bar',color =['red','green'])

pit.title('Distrubution of data by Gender')
pit.xlabel('Marital Status')
pit.ylabel('Monthly income')
pit.show()
pit.figure(figsize =(10,8))

# %%
#calcultaing the online order delivery details

plt.figure(figsize=(15,15))
for i, column in enumerate(influence):
    plt.subplot(3, 3, i+1)
    sns.countplot(data=st, x=column)
    plt.title(f'Does {column}\nInfluence using online food delivery?')
    plt.tight_layout()

# %%
##calcultaing attribute of online order delivery conellation details analysis

plt.figure(figsize=(15,15))
for i, column in enumerate(cancelation):
    plt.subplot(3, 3, i+1)
    sns.countplot(data=st, x=column)
    plt.title(f'Can the {column} \nlead to cancellation?')
    plt.tight_layout()
